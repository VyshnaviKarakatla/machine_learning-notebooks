# %%
import os
import time
import subprocess

# === CONFIGURATION ===
WATCH_DIR = r"C:\Users\lokes\OneDrive\Documents\Projects\machine_learning-notebooks"
BRANCH = "main"
INTERVAL = 5  # seconds

def git_run(cmd, cwd):
    """Run a Git command and return output."""
    return subprocess.run(cmd, cwd=cwd, capture_output=True, text=True)

def watch_and_sync(directory, branch="main", interval=5):
    print(f"Watching folder: {directory}")
    
    os.chdir(directory)

    # Ensure Git repo exists
    if not os.path.exists(os.path.join(directory, ".git")):
        print("Initializing Git repo...")
        git_run(["git", "init"], directory)
        git_run(["git", "branch", "-M", branch], directory)
        print("Git repo initialized.\n")

    last_snapshot = {}

    while True:
        current_snapshot = {}

        # Scan notebook or python files
        for root, dirs, files in os.walk(directory):
            for filename in files:
                if filename.endswith(".ipynb") or filename.endswith(".py"):
                    filepath = os.path.join(root, filename)
                    current_snapshot[filepath] = os.path.getmtime(filepath)

        # Identify changed files
        changed_files = [
            f for f in current_snapshot
            if f not in last_snapshot or current_snapshot[f] != last_snapshot[f]
        ]

        if changed_files:
            print("Changes detected:", changed_files)

            git_run(["git", "add", "."], directory)
            git_run(["git", "commit", "-m", "Auto-sync commit"], directory)
            git_run(["git", "push", "-u", "origin", branch], directory)

            print("Changes pushed.\n")

        last_snapshot = current_snapshot
        time.sleep(interval)

# Run watcher
watch_and_sync(WATCH_DIR, branch=BRANCH, interval=INTERVAL)
# Out:
# Watching folder: C:\Users\lokes\OneDrive\Documents\Projects\machine_learning-notebooks
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\01_linear_regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\02_underfitting_overfitting.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\03_polynomial_regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\04_logistic_regression(classification).ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\05_Encoding.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\06_normalization.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\07_standardization.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\08_accuracy_precision_recall_f1-score.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\09_confusion_matrix.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\10_regularization.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\auto_sync.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\01_linear_regression-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\02_underfitting_overfitting-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\03_polynomial_regression-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\04_logistic_regression(classification)-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\05_Encoding-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\06_normalization-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\07_standardization-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\08_accuracy_precision_recall_f1-score-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\09_confusion_matrix-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\10_regularization-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\auto_sync-checkpoint.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\data\\faker.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\data\\.ipynb_checkpoints\\faker-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\auto_sync.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\11_L2_Regularization_Ridge_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\11_L2_Regularization_Ridge_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\Untitled.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\Untitled-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\12_L1_Regularization_Lasso-Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\12_L1_Regularization_Lasso-Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\12_L1_Regularization_Lasso_Regression.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\12_L1_Regularization_Lasso_Regression-checkpoint.ipynb']
# Changes pushed.
#
# Changes detected: ['C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\Untitled.ipynb', 'C:\\Users\\lokes\\OneDrive\\Documents\\Projects\\machine_learning-notebooks\\.ipynb_checkpoints\\Untitled-checkpoint.ipynb']
# Changes pushed.
