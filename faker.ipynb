# %% [raw]
# pip install faker

# %%
from faker import Faker

# %%
fake=Faker()

# %%
fake.country()
# Out:
# 'Qatar'

# %%
fake.country()
# Out:
# 'Andorra'

# %%
for i in range(1,11):
    print(fake.country())
# Out:
# Paraguay
# Mozambique
# Bahrain
# Guyana
# Bahamas
# Cameroon
# Comoros
# Djibouti
# Wallis and Futuna
# Morocco

# %%
for i in range(1,11):
    print(fake.name())
# Out:
# Ana Phillips
# Marcus Kirk
# Richard Clark
# Donna Edwards
# Alexis Gonzalez
# Mary Reilly
# Daniel Anderson
# Adrian Peck
# Jeffery Powers
# Megan Evans

# %%
for i in range(1,11):
    print(fake.email())
# Out:
# parkerkenneth@example.org
# mccoyamber@example.net
# petersonjared@example.net
# navarrodaniel@example.org
# ijones@example.net
# catherinedunn@example.com
# josephharrison@example.net
# vmcmillan@example.net
# ronald26@example.org
# dstanton@example.net

# %%
for i in range(1,11):
    print(fake.address())
# Out:
# PSC 0955, Box 8239
# APO AE 51716
# 470 Montes Corners
# Samanthatown, ID 57257
# 47704 Michael Haven Suite 984
# West Rodney, AS 31454
# 10554 George Shores
# Chadborough, CO 52842
# 79311 Wells Divide
# Fryburgh, NE 69422
# 86876 Larsen Green
# Lake Cynthia, NJ 11971
# 3482 Nathan Knolls Apt. 979
# Joefort, RI 64791
# 434 Brooks Cove Apt. 122
# Port Kenneth, IA 08209
# PSC 6257, Box 6661
# APO AP 38256
# 07705 Renee Squares
# New Derekchester, MD 53265
