# %%
#L2 Regularization
#Ridge Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import (LinearRegression,Ridge)
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(40)
x=np.random.randn(100,3)
y=3*x[:,0]+2*x[:,1]+5*x[:,2]+np.random.randn(100)*0.5

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)

# %%
#Linear regression
lr=LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_lr=lr.predict(x_test)

# %%
#Ridge Regression
ridge=Ridge(alpha=10)

# %%
ridge.fit(x_train,y_train)
# Out:
# Ridge(alpha=10)

# %%
y_pred_ridge=ridge.predict(x_test)

# %%
print('Coefficient of Linear: ',lr.coef_)
print('Coefficient of Ridge: ',ridge.coef_)
# Out:
# Coefficient of Linear:  [3.0050451  1.98031143 5.01888657]
# Coefficient of Ridge:  [2.48847066 1.75682635 4.39109972]

# %%
print('MSE of linear: ',mean_squared_error(y_test,y_pred_lr))
print('MSE of Ridge: ',mean_squared_error(y_test,y_pred_ridge))
# Out:
# MSE of linear:  0.26150894248698575
# MSE of Ridge:  1.4840669588285293

# %%
#Here my ridge performed bad as dataset is very simple, ridge adds bias, choice of aplha is high

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import (LinearRegression,Ridge)
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
np.random.seed(40)
x=np.random.randn(100,3)
y=3*x[:,0]+2*x[:,1]+5*x[:,2]+np.random.randn(100)*0.5
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=40)
lr=LinearRegression()
lr.fit(x_train,y_train)
y_pred_lr=lr.predict(x_test)

alpha=[0.01,0.1,10,100]
mse_ridge=[]
for alpha in alpha:
    ridge=Ridge(alpha=alpha)
    ridge.fit(x_train,y_train)
    y_pred_ridge=ridge.predict(x_test)
mse_ridge.append(mean_squared_error(y_test,y_pred_ridge))
mse_lr=mean_squared_error(y_test,y_pred_lr)

# %%
plt.figure(figsize=(7,5))
plt.plot(alpha,mse_ridge,marker='o',label='Ridge MSE')
plt.axhline(y=mse_lr,color='r',linestyle='--',label='Linear MSE')
plt.xscale('log')
plt.xlabel('Alpha Log Scale')
plt.ylabel('Mean Squared Error')
plt.title('Effect of Ridge Regression')
plt.legend()
plt.grid()
plt.show()
