# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df=pd.read_csv('landrates.csv')
df
# Out:
#    area    rate
# 0  1600  450000
# 1  1800  480000
# 2  2000  500000
# 3  2200  540000
# 4  2600  560000
# 5  3000  580000

# %%
# %matplotlib inline
plt.figure(figsize=(5,4))
plt.xlabel('Land Area (sqft)')
plt.ylabel('Price')
plt.scatter(df.area,df.rate,color='r',marker='+')

# %%
model=linear_model.LinearRegression()
model.fit(df[['rate']],df.area)
# Out:
# LinearRegression()

# %%
model.predict([[2300]])
# Out:
# C:\Users\lokes\anaconda3\envs\statsenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-3008.56074766])

# %%
model.predict([[2300],[2400],[2500]])
# Out:
# C:\Users\lokes\anaconda3\envs\statsenv\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([-3008.56074766, -3007.55140187, -3006.54205607])

# %%
model.coef_
# Out:
# array([0.01009346])

# %%
model.intercept_
# Out:
# np.float64(-3031.775700934578)

# %%
df1=pd.read_csv('areas.csv')

# %%
prd1 = model.predict(df1)

# %%
df1.to_csv('newpredrates.csv',index=False)

# %%
# %matplotlib inline
plt.figure(figsize=(5,3))
plt.xlabel('Land Area (sqft)')
plt.ylabel('Price')
plt.scatter(df.area,df.rate,color='r',marker='+')
plt.plot(df['area'],model.predict(df[['area']]))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[39], line 6
#       4 plt.ylabel('Price')
#       5 plt.scatter(df.area,df.rate,color='r',marker='+')
# ----> 6 plt.plot(df['area'],model.predict(df[['area']]))
#
# File ~\anaconda3\envs\statsenv\Lib\site-packages\sklearn\linear_model\_base.py:298, in LinearModel.predict(self, X)
#     284 def predict(self, X):
#     285     """
#     286     Predict using the linear model.
#     287
#    (...)    296         Returns predicted values.
#     297     """
# --> 298     return self._decision_function(X)
#
# File ~\anaconda3\envs\statsenv\Lib\site-packages\sklearn\linear_model\_base.py:277, in LinearModel._decision_function(self, X)
#     274 def _decision_function(self, X):
#     275     check_is_fitted(self)
# --> 277     X = validate_data(self, X, accept_sparse=["csr", "csc", "coo"], reset=False)
#     278     coef_ = self.coef_
#     279     if coef_.ndim == 1:
#
# File ~\anaconda3\envs\statsenv\Lib\site-packages\sklearn\utils\validation.py:2929, in validate_data(_estimator, X, y, reset, validate_separately, skip_check_array, **check_params)
#    2845 def validate_data(
#    2846     _estimator,
#    2847     /,
#    (...)   2853     **check_params,
#    2854 ):
#    2855     """Validate input data and set or check feature names and counts of the input.
#    2856
#    2857     This helper function should be used in an estimator that requires input
#    (...)   2927         validated.
#    2928     """
# -> 2929     _check_feature_names(_estimator, X, reset=reset)
#    2930     tags = get_tags(_estimator)
#    2931     if y is None and tags.target_tags.required:
#
# File ~\anaconda3\envs\statsenv\Lib\site-packages\sklearn\utils\validation.py:2787, in _check_feature_names(estimator, X, reset)
#    2784 if not missing_names and not unexpected_names:
#    2785     message += "Feature names must be in the same order as they were in fit.\n"
# -> 2787 raise ValueError(message)
#
# ValueError: The feature names should match those that were passed during fit.
# Feature names unseen at fit time:
# - area
# Feature names seen at fit time, yet now missing:
# - rate
