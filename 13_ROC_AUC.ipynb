# %%
#ROC
#AUC

# %%
#ROC

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import roc_curve,roc_auc_score

# %%
x,y=make_classification(n_samples=500,n_features=10,n_classes=2,random_state=40)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=40)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_probs=model.predict_proba(x_test)[:,1]

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_probs)

# %%
auc_score=roc_auc_score(y_test,y_probs)

# %%
plt.figure(figsize=(5,3))
plt.plot(fpr,tpr,label='ROC Curve')
plt.plot([0,1],[0,1],linestyle='--',color='red',label='Random Estimation')
plt.xlabel('False Positive Rate (FPR)')
plt.ylabel('True Positive Rate(TPR)')
plt.title('ROC Curve')
plt.legend()
plt.grid()
plt.show()

# %%
#AUC

# %%
#AUC using logistic Regression

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification
from sklearn.metrics import roc_auc_score

# %%
x,y=make_classification(n_samples=500,n_features=10,random_state=40)

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=40)

# %%
model=LogisticRegression()
model.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_probs=model.predict_proba(x_test)[:,1]

# %% [raw]
# auc_logreg=roc_auc_score(y_test,y_probs)

# %%
# AUC Manual

# %%
x_true=np.array([1,0,1,0,1,0])
y_scores=np.array([0.9,0.8,0.7,0.6,0.4,0.3])

# %%
auc_manual=roc_auc_score(x_true,y_scores)

# %%
print(auc_logreg,auc_manual)
# Out:
# 0.9315491507977356 0.6666666666666667
