# %%
#K-Means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data={
    'income':[15,16,17,20,21,22,45,46,47,48,80,85,86,88,90],
    'spendingscore':[39,81,6,77,40,76,6,8,]
}
