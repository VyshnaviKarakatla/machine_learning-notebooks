# %%
#K-Means

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans

# %%
data={
    'income':[15,16,17,20,21,22,45,46,47,48,80,85,86,88,90],
    'spendingscore':[39,81,6,77,40,76,6,8,7,5,85,82,84,83,87]
}

# %%
df=pd.DataFrame(data)

# %%
km=KMeans(n_clusters=3,random_state=40,n_init=10)

# %%
km.fit(df)
# Out:
# C:\Users\lokes\anaconda3\envs\statsenv\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(n_clusters=3, n_init=10, random_state=40)

# %%
df['cluster']=km.labels_

# %%
plt.figure(figsize=(3,5))
plt.scatter(df['income'],df['spendingscore'],c=df[])
plt.xlabel('Income')
plt.ylabel('SpendingScore')
plt.title('K-Means')
plt.show()
