# %%
#Decision Tree

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_
from sklearn import DecisionTreeClassifier
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 4
#       2 import matplotlib.pyplot as plt
#       3 from sklearn import datasets
# ----> 4 from sklearn import DecisionTreeClassifier
#
# ImportError: cannot import name 'DecisionTreeClassifier' from 'sklearn' (C:\Users\lokes\anaconda3\envs\statsenv\Lib\site-packages\sklearn\__init__.py)
