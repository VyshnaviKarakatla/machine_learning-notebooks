# %%
#Normalization

# %%
#Min-Max Scale normalization

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
data=pd.read_csv('Wine.csv',usecols=[0,1,2])

# %%
data.columns
# Out:
# Index(['class', 'Alcohol', 'Malic acid'], dtype='object')

# %%
#Kernal Density Estimation (kde)
sns.histplot(data['Alcohol'],kde=True)
# Out:
# <Axes: xlabel='Alcohol', ylabel='Count'>

# %%
sns.kdeplot(data['Alcohol'])
# Out:
# <Axes: xlabel='Alcohol', ylabel='Density'>

# %%
sns.histplot(data['Malic acid'],kde=True)
# Out:
# <Axes: xlabel='Malic acid', ylabel='Count'>

# %%
sns.kdeplot(data['Malic acid'])
# Out:
# <Axes: xlabel='Malic acid', ylabel='Density'>
